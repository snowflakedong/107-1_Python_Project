# %% [markdown]
# #### 讀取需要的函式庫

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from IPython.display import clear_output
from wordcloud import WordCloud
from PIL import Image
from func import *
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import jieba
import sys
import re
import os
# re -> \d for number, \s for any space (\t\r\n...)

# %% [markdown]
# #### 讀取資料夾中的資料

# %%
#path = '../../107-1PythonSampleCode/week_5/task_5/*.txt'
path = 'C:/Users/ASUS/Desktop/資本市場/newpython-master/newpython-master/finaceKAM/KAM整合檔/*.txt'
title, data = readdir(path)
# Out:
# Number of files : 3

# %% [markdown]
# #### 顯示部份資料內容

# %%
for i in range(len(data)):
    print('----Document : {0}----'.format(title[i]))
    print(data[i][:10], '...', data[i][-10:-1], sep='\n', end='\n\n')
# Out:
# ----Document : 全部保險業----
#
# 關鍵查核事項
#
# ...
# .08)%。"
#
#
# ----Document : 全部證券業----
#
#
# 關鍵查核事項
# ...
# 案，備供參考。
#
#
# ----Document : 全部銀行業----
#
# 關
# ...
# 廢損失之計算。

# %% [markdown]
# #### 新增詞彙至自定義停止詞彙中

# %%
stopword = ['一','二','三','四','五','六','七','八','九','十','年','月','日','用','淨','利','值','前',
             '據','談','自','至','曾','出',
            '合','最','供','而','個','很','得','達','家','進','所','夏','若','邱','但','中','可',
            '他','我','列','將','對','之','率','已','由','佔','本','日','月','年','另','故','於',
            '較','請','再','經','也','在','依','到','等','或','大','認列','不僅','讓','相關','最終',
            '把','沒','及','過去','認為','為','按','比','仍','係','後','及與','以','時','該','的',
            '並','更','就','註','有','事','來','不','從','堺','權','卻','說','要','今','度',
            '手','才','又','其','長','了','百','億','元','例如','可能','由於','因此','土城','一份',
            '上午','這份','多','赴','和','與','是','約','就是','只是','但是','如果','附註','部分',
            '事項','各位','品牌','集團','幅度','資產','新','台幣','日圓','億日圓','機構','面板','日元',
            '企業','報導','媒體','目前','提案','經營','實地','大阪','億元','以及','代工','一步','第二',
            '雙方','方案','分析','接受','成為','事業','目前','高橋','董事','營業','受到','提供','使用',
            '本年','說明','現金','成本','營業外','收入','結轉','分攤','其他','影響財務','詳合','結果',
            '不是','是否','最高','記者','超過','兩家','主幹','我們','除了','自己','立刻','','日本',
            '之間','不過','今天','然而','此外','工廠','預測','如下','之一','附註','附','註','其中',
            '因為','查核','報告增加','會計','相對','仟元','金額','權益','能力利益','股東','合理性',
            '假設','無形','上','開關鍵','模型','支出','控制','計算','資金評估','報告','因應','仟元',
            '金額','權益','假設','無形','上','模型','支出','控制','計算資金','評估','人次','重大',
            '資訊','總額','民國','估計','一副','公司','年度','包括','正確性','正','確性','減損','共為',
            '預估','預算','去年同期','應該','雖然','下午','要求','一樣','一家','維持','公開','整體',
            '表示','特性','市場','科目','發生','年本','重要','判斷','主要','流量','意見','關鍵','同期',
            '評價','正確','地區','總資產','執行','程序','測試','稅後淨利','股份有限公司','蘋果','鴻海',
            '夏普','郭台銘','鴻夏戀','iPhone','1','2','3','4','5','6','7','8','9','0','NT','2012',
            '10','三星','供應商','INCJ','案','LG','會','下','買','電子','清單','向','都',
            '能力','進','廠','內','購','併','這','看','人','被','能','外界','指出','五日','不同','陷入',
            '出現','一年','什麼','安倍','這個','可以','一個','同時','去年','部門','二月','這是','月底',
            '完成','財務','今年','階段','子公司','條件','引述','召開','擁有','有助','持有','進入','旗下',
            '已經','入座','罩','業務','顯示','尺寸','萬張','取得','高達','持續','進行','人士','提出',
            '社長','加工','內容','總部','沒有','加上','決定','群創','最大','四年','代廠','做','鴻','高',
            '市','不會','傳出','文件','客戶超過','SDP','JDI','IGZO','Display','WitsView','NHK',
            '12','7000','3500','2015','2016','25','30','000','29','一下子', '一九', '一九九九年', '一二八',
             '一兆日圓', '一再', '一勞永逸', '一千七百', '一千五百', '一口', '一向', '一哩路', '一四會計', '一回',
             '一城', '一塊', '一夕', '一天', '一套', '一季', '一宗', '一役', '一心', '一成則', '一手', '一把', '一搏', 
             '一擲', '一攤', '一支', '一方', '一月', '一月底', '一樁', '一比', '一流', '一片', '一百', '一百三十元', 
             '一百九十', '一站', '一筆', '一職', '一舉', '一般性', '一起', '一路', '一身', '一連串', '一進',
            '一下子', '一部', '一項', '一顆', '七七', '七五', '七千', '七四', '七年', '三九', '三五', '三個', '三億',
            '三兆台幣', '三公', '三六', '三十九', '三十五', '三十分', '三千', '三名', '三大會', '三成', '三支', '三方',
            '三月', '三月底', '三率', '三筆', '三等', '三箭', '三緘其口', '三角', '三足鼎立', '三降', '三點', '上個', '上千',
            '上升', '上半年', '上台', '上周', '上層', '上層察覺', '上市', '上揚', '上攻', '上放著', '上旬', '上極',
           '一及', '一所', '一月份', '一期', '一系列', '一類', '七中', '七日', '三七', '三信商業銀行', '三商美邦人壽保險', '三四', 
            '上之關', '上應', '上海商業儲蓄銀行', '上開', '下個', '下單方式', '下述', '下針','不利', '不動', '不得', '不易', '不當',
            '不確', '不符', '不良', '不論', '且屬', '並不', '並且', '並仰', '並依', '並個', '並列','並同', '並執', '並委', '並將', '並對',
            '並就', '並按',  '並於期','所得','未報','記載','元大期貨','群益金鼎證券','部位','中國人壽保險','泰安產物保險','臺銀人壽保險','及其',
            '請詳','該等','上述','宏泰人壽','合併財務報表','符合','臺灣銀行','全球人壽保險','旺旺友聯產物保險','新光人壽保險','富邦人壽保險',
            '國泰人壽','國泰世紀產物保險','合併財務報告','合併','報表','105','106','統一','大慶','宏遠','華南產物保險','三商美', '下限', '並參考', 
            '並比', '並決', '並決定', '並測', '並無', '並確', '並經本', '並經過', '並自', '並計', '並評', '並重編', '中之部', '中保', '中國', '中央再保險',
            '中將', '中心', '中較', '中選樣', '主管', '主計', '之二', '之人員', '之估', '之依', '之保單', '之保費', '之備', '之內', '之公', '之分', '之分類', 
            '之加', '之可回', '之可觀', '之品', '之國內', '之國家', '之壓', '之妥', '之子行', '之客', '之專', '之後續', '之性質', '之應','之應用', '之戶', '之手', 
            '之折', '之損', '之放', '之新', '之明', '之核', '之機制', '之正確', '之淨', '之減', '之準', '之潛', '之營', '之理論', '之相', '之範圍', '之股', '之要', 
            '之覆審', '之規', '之計息', '之設', '之認', '之課', '之證', '之責', '之辨別', '之辨識', '之選用', '之重', '之金', '之開', '之關', '之非', '之額外', '之風', 
            '之餘額', '之高', '九十七', '九十六年', '九月', '予專', '予星展', '事期貨', '事錄', '二三','二二', '二十七', '二十二', '二十五日', '二者', '五十', '五底',
            '五月', '交互', '亦針', '亦需', '享淨值', '京城商業銀行', '人員依','人工', '人數', '人民', '人股', '他人','仟元減', '代理人', '代行',
            '令及', '令規定', '令規範', '以上', '以個', '以公','以前', '以前年度', '以往', '以成', '以攤銷', '以本', '以權責', '以此', '以比', '以監', '以致', '以融',
            '以評', '以選樣','以類', '以驗', '任一', '任準備', '份額', '企金', '估並', '估其', '估分', '估及', '估整體', '估理', '估結果', '估表所載', '位處分', '低迷',
            '佐證', '佔淨', '何選擇', '作出', '作成', '使得', '使融', '來帳', '例約', '供出', '依中華', '依公', '依其會', '依其過', '依參考', '依實際', '依審', '依循',
            '依性質', '依所定',  '依此', '依現','依經', '依賴', '依過', '依險種', '保合約', '保品', '保戶', '保書', '保產', '保管', '保證', '保費', '保費及', '保費收',
            '修正', '借保戶', '值以', '值估', '值作', '值間', '做出', '做成','健全', '偵測', '備之','備查', '備評','事故','交換', '交易對象', '人壽', '付息', '代表性',
            '低估', '住宅', '依債權', '依權責', '依融資', '保單','偏誤', '停售', '停業', '停業單', '備抵', '備金', '催收', '債之', '債券及', '債務人', '債及', '債權',
            '債準備', '債表所計', '債適', '債金額', '價所', '價方', '價模', '價機制', '價為', '價資訊', '億元並', '億建築', '償還', '優惠', '允當及',  
            '元大商業銀行', '兆豐', '光人壽','之主', '之評', '之資本','免提', '入值', '入入帳', '內部專', '內部控', '內部控制全年執行之有效性', '內部評',
            '全數', '全球', '全行', '全部', '全面', '兩者', '兩類', '八中', '八及', '八月','公告', '公布', '公式', '公認', '公開報', '六中', '六底', '共同', 
            '其依', '其公', '其列', '其匯入', '其應', '其有', '其次', '其為', '其為關', '其金', '其金額', '其餘','再區', '再將', '凱基商', '凱基商業銀行', '出並',
            '出口', '出租', '出結', '出該', '函證','函釋採', '分保', '分割', '分子', '分派', '分為', '分組', '分行', '分配', '切性', '列之金額', '列為民', 
            '列管', '判定', '別之戶', '別具', '別及', '別明細', '別設', '別項', '利之', '利用', '到期日', '制之', '制度', '制訂', '則依', '則將','十一日', '十七年', '十七所',
            '卅三', '卅二', '卅八', '南山', '南山人壽保險','製' ,'本會計師','管理階層','予以','涉及','有關','形成','組合','衡量','針對','處理','如','產生'
           ,'依規定','依規範','則由','及並','區之','並不對','具類','採用','福邦','康和綜合證券','及三一','及二一','及保','則應將','及個','及備', '及入',
            '則採','泰安產物','及區域', '及子', '及子公', '及層級','及分', '及利潤', '及利變', '及區域','則第', '則需', '則須', '前期','遠雄人壽保險','程中','公司競爭力',
            '公司股票','大展','函釋','臺灣新光商業銀行','銀行','單獨','指依','參閱','富邦產物保險','台灣產物保險','系統','關鍵查核事項','台中商業銀行','日前','最為','無',
           '國泰世華商業銀行','澳盛','第一商業銀行','參考','之過','分類','台灣','依據','群益','資料','方法','31','參數','去損', '去理', '參照', '參與', '及佐證', '及應', '及承擔', '及折', '及持續', '及採', '及損', '及數', '及方', 
            '及施', '及會計', '及期', '及業界', '及永續', '及流', '及淨', '及測', '及監','可供', '可分', '可實', '可得', '可收回', '可比', '可能性', '可觀察資訊', '可觀察跡', '可觀查', '台之子',
            '台北富邦商業銀行', '台新', '台新金', '台新銀', '台灣人壽', '台灣人壽集團', '史損', '司以','彰化銀行','本事','務所','根據','各季', '各授', '各暫', '各種準', '各險', 
            '各險種', '各類','合約皆須','勤業','另亦須', '另因', '另外', '另為','合作金庫商業銀行','及符', '及結', '及處', '及規', '及評', '及變', '及負', '及財', '及運算', '及過', '及遠',
            '及遠鼎', '及金額','安泰商業銀行','瑞興商業銀行','聯邦','遠東國際商銀','永豐商業銀行','玉山商業銀行','遠東','星展','高雄銀行','建置','匯豐','花旗','臺灣中小企業銀行','易有'
           ,'確會','學會','釋令','收取','\r\n','\t','\u3000','未上市','詳個體','華泰商業銀行','遠東國際商業銀行','日盛國際商業銀行','陽信商業銀行','華南商業銀行']
puncs_Full = '！？｡＂＃＄％＆＇（）()＊＋，－／：；＜＝＞＠［＼］$＾□＿○｀｛｜｝～｟｠｢｣､、〃》「」『』【】〔〕〖〗〘〙〚〛〜〝〞〟〰〾〿–—‘’‛“”„‟…‧﹏.。'
puncs_Half = "!?.#$%&'()*+,-/:;<=>@[]^_{}|~\\\""
#savetofile('./stopword.txt', [stopwords, puncs_Full, puncs_Half])

# %%
#stopword = readdir('./stopword.txt')[1][0].split('\n')
stopword.append('\n')
stopword[0:10]
# Out:
# ['一', '二', '三', '四', '五', '六', '七', '八', '九', '十']

# %% [markdown]
# ## 新增詞彙至自定義詞庫，並匯入該詞庫

# %%
jieba.load_userdict('C:/Users/ASUS/Desktop/資本市場/newpython-master/newpython-master/finaceKAM/dict.txt')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ASUS\AppData\Local\Temp\jieba.cache
# Loading model cost 1.926 seconds.
# Prefix dict has been built succesfully.

# %% [markdown]
# #### 利用 jieba 對文件進行斷字，並統計字詞頻率，顯示前十名資料

# %%
wordDictionary = []
for i in range(len(data)):
    seg_list = jieba.cut(data[i], cut_all=False)
    seg_list = list(seg_list)
    wordDict = {}
    for w in seg_list:
        if (w not in stopword) and (w not in puncs_Full) and (w not in puncs_Half):
            if w in wordDict:
                wordDict[w] = wordDict[w] + 1
            else:
                wordDict[w] = 1
    wordDictionary.append(wordDict)
    print('Number of word in document ({0}) : '.format(title[i]), len(wordDict))
    sort = sorted(wordDict.items(), key=lambda x: x[1], reverse = True)
    print(sort[0:10])
    data[i] = ','.join(jieba.cut(data[i], cut_all=False))
# Out:
# Number of word in document (全部保險業) :  1284
# [(' ', 1351), ('保險', 549), ('負債', 392), ('準備', 277), ('精算', 222), ('公允價值', 207), ('賠款', 179), ('金融工具', 152), ('專業', 126), ('金融資產', 105)]
# Number of word in document (全部證券業) :  670
# [(' ', 500), ('證券', 90), ('經紀手續費收入', 53), ('公允價值', 44), ('會計政策', 34), ('金融工具', 27), ('出售', 26), ('商譽', 26), ('金融資產', 25), ('交易', 25)]
# Number of word in document (全部銀行業) :  1816
# [('放款', 467), ('減損評估', 207), ('貼現及放款', 203), ('提列', 201), ('應收款', 195), ('損失', 184), ('公允價值', 141), ('金融工具', 140), ('備抵呆帳', 128), ('商譽', 127)]

# %% [markdown]
# #### 顯示各文件低於閥值 (limit) 的字詞

# %%
limit = 0
wordsperdocument = 50
for i in range(len(data)):
    count = 0
    print('----Document : {0}----'.format(title[i]))
    for ind, value in wordDictionary[0].items():
        if (value <= limit) & (count != wordsperdocument):
            count += 1
            print(ind, end = ', ')
    print()
# Out:
# ----Document : 全部保險業----
#
# ----Document : 全部證券業----
#
# ----Document : 全部銀行業----

# %% [markdown]
# #### 利用 wordDictionary 移除出現次數低於閥值 (limit) 的字詞，並顯示部份結果

# %%
for i in range(len(data)):
    for key, value in wordDictionary[0].items():
        if value <= limit:
            data[i] = data[i].replace(key, '')
    print('document :', title[i])
    print(data[i][:50], '...', data[i][-50:-1], sep='', end='\n\n')
# Out:
# document : 全部保險業
#
# ,關鍵查核事項,
# ,　,　,關鍵查核事項,係,指依,本會計師,之,專業,判斷,，,對,泰安產物...,之份額,分別,占,稅前淨利,之,(,5.63,),%,及,(,18.08,),%,。,",
# ,
#
# document : 全部證券業
#
# ,
# ,關鍵查核事項,
# ,
# , , , , ,關鍵查核事項,係,指依,本會計師,之,專業,判...告,，,並經,本會計師,
# ,出具,無,保留,意見,之,查核報告,在案,，,備供,參考,。,
# ,
#
# document : 全部銀行業
# 	,	,	,	,	,	,	,
# ,關鍵查核事項,	,	,	,	,	,	,	,	,
# ,關鍵查核事項,...；,針對,相關,業務,未,列入,分割,讓,與,之,資產,，,覆核,報廢,損失,之,計算,。,
# ,

# %% [markdown]
# #### 移除所有標點符號、非中文英文數字之資料

# %%
for i in range(len(data)):
    data[i] = re.sub('[^\u4e00-\u9fff,]', '', data[i])
#[^\u4e00-\u9fff A-Za-z0-9]

# %% [markdown]
# #### 印出部份斷字結果

# %%
for i in range(len(data)):
    print('document :', title[i])
    print(data[i][:20], ' ... ', data[i][-20:-1], sep='', end='\n\n')
# Out:
# document : 全部保險業
# ,關鍵查核事項,,,,關鍵查核事項,係, ... 稅前淨利,之,,,,,及,,,,,,,
#
# document : 全部證券業
# ,,關鍵查核事項,,,,,,,關鍵查核事 ... ,之,查核報告,在案,,備供,參考,,
#
# document : 全部銀行業
# ,,,,,,,,關鍵查核事項,,,,,, ... 資產,,覆核,報廢,損失,之,計算,,

# %% [markdown]
# #### 初始化 TFIDF 物件，用以計算 tfidf

# %%
tfidf_vectorizer = TfidfVectorizer(max_df = 1, min_df = 0, analyzer = 'word'
                                   , stop_words = stopword, max_features = 10000)
#tfidf_vectorizer = CountVectorizer(stop_words = stopword)

# %% [markdown]
# #### 顯示初始化時輸入的停止詞彙

# %%
print(tfidf_vectorizer.get_stop_words())
# Out:
# frozenset({'', '涉及', '之理論', '一九', '利用', '2', '之相', '新光人壽保險', '四年', '財務', '列為民', '一勞永逸', '債權', '並委', '並且', '依參考', '七五', '本會計師', '預算', '新', '下限', '合', '之分', '不論', '其金', '可觀查', '安倍', '未報', '接受', '及過', '各暫', '學會', '無', '鴻海', '務所', '25', '保書', '及永續', '台灣產物保險', '二者', '及承擔', '過去', '指依', '一進', '列', '把', '一方', '所', '指出', '宏泰人壽', '分析', '以個', '和', '債金額', '管理階層', '也', '之保費', '下述', '上應', '制度', '報表', '不會', '一比', '提出', '這', '三五', '之新', '我', '部門', '採用', '債務人', '健全', '依融資', '一套', '偏誤', '可得', '媒體', '依經', '是', '赴', '一舉', '分割', '就是', '三九', '及方', '如下', '日前', '偵測', '年度', '價方', '令及', '一把', '之加', '三公', '分派', '日本', '整體', '七年', '利之', '衡量', '之子行', '並經本', '及個', '計算資金', '不得', '單獨', '執行', '廠', '一百九十', '台新金', '估表所載', '依險種', '及會計', '上極', '並將', '記載', '予星展', '以權責', '現金', '任一', '卻', '附註', '事業', '子公司', '000', '交換', '之二', '銀行', '予以', '二十二', '前', '三等', '以本', '一份', '幅度', '以此', '高', '及與', '國泰人壽', '以選樣', '去損', '一心', '作成', '安泰商業銀行', '前期', '保戶', '下', '值', '可', '事', '立刻', '假設', '一個', '一起', '下單方式', '之專', '全球', '一月份', '三個', '估理', '市', '一月', '判定', '能力', '上述', '然而', '與', '了', '其他', '一手', '可能性', '一二八', '合約皆須', '資訊', '不僅', '一類', '收入', '合併財務報告', '2012', '催收', '合併', '根據', '函釋', '估整體', '支出', '人次', '減損', '一回', '及利潤', '及二一', '及數', '要求', '台之子', '勤業', '卅二', '有', '相對', '別及', '程序', '依規定', '事故', '如', '系統', '保費收', '及遠鼎', '上放著', '家', '0', '附', '一站', '內部專', '公認', '兩類', '度', '日元', '中央再保險', '華南商業銀行', '其為關', '及損', '以及', '取得', '合作金庫商業銀行', '做成', '全部', '二二', '其次', '維持', '一月底', '對', '陷入', 'NHK', '另亦須', '低估', '之人員', '之主', '將', '較', '代表性', '何選擇', '一城', '之明', '例約', '富邦人壽保險', '出該', '日盛國際商業銀行', '及測', '加工', '7000', '一百', '之手', 'NT', '保單', '後', '不易', '事項', '各位', '一四會計', '三六', '依賴', '台灣', '另為', '及規', '瑞興商業銀行', '其列', '參考', '各季', '公式', '花旗', '萬張', '臺灣銀行', '供應商', '一步', '一口', '上旬', '債券及', '據', '參照', '一搏', '到', '並對', '所得', '八及', '之一', '於', '什麼', '其中', '尺寸', '一連串', '全面', '29', '一年', '允當及', '十七年', '今天', '群益', '及處', '七七', '元大期貨', '清單', '最大', '七日', '邱', '總資產', '三支', '南山', '七中', '主要', '住宅', '之股', '六中', '股東', '人壽', '列之金額', '之折', '兩者', '之後續', '依據', '卅三', '上之關', '\t', '3', '之過', '及業界', '10', '八月', '不過', 'JDI', '旗下', '並仰', '如果', '我們', '之課', '合併財務報表', '今', '三千', '之公', '時', '比', '一塊', '一及', '代行', '六底', '企業', '有關', '但是', '各類', '億元並', '其為', '臺銀人壽保險', '亦針', '一擲', '106', '之金', '及財', '之保單', '各險種', '上開', '一', '以', '之淨', '雙方', '雖然', '\r\n', '\n', '是否', '五', '下午', '五月', '主管', '發生', '若', '供出', '資料', '三月', '已經', '及應', '一宗', '面板', '上層察覺', '之估', '自', '之性質', '及符', '玉山商業銀行', 'iPhone', '機構', '保費及', '二十五日', '備之', '大慶', '之損', '公司股票', '併', '曾', '擁有', '五底', '泰安產物', '中國人壽保險', '及結', '預測', '外界', '三緘其口', '關鍵查核事項', 'INCJ', '從', '債適', '依循', '上海商業儲蓄銀行', '估計', '全數', '史損', '制之', '不利', '高雄銀行', '更', '召開', '價所', '公布', '部位', '只是', '一百三十元', '之客', '借保戶', '說明', '函釋採', '三七', '六', '此外', '之品', '債及', '高橋', '及淨', '可能', '由', '年本', '業務', '一千五百', '分組', '以類', '共同', '統一', '之風', '令規定', '收取', '億元', '並不', '二', '三角', '別項', '公開報', '代廠', '由於', '五十', '則依', '群益金鼎證券', '一下子', '並決定', '確性', '他人', '以監', '台中商業銀行', '及金額', '予專', '依審', '估並', '另', '付息', '以致', '再區', '估及', '\u3000', '該等', '之應用', '之非', 'IGZO', '本事', '可供', '依中華', '切性', '易有', '仟元', '去年', '客戶超過', '夏', '台灣人壽集團', '出並', '備評', '影響財務', 'Display', '及', '並於期', '台新銀', '兩家', '傳出', '三億', '之戶', '這份', '買', '一樣', '之評', '並', '報告增加', '遠東國際商業銀行', '凱基商業銀行', '7', '公開', '並評', '一身', '高達', '內部控', '成本', '上周', '依此', '一成則', '供', '超過', '之證', '形成', '上半年', '及持續', '無形', '臺灣中小企業銀行', '要', '認為', '一天', '之重', '台灣人壽', '重大', '之要', '備查', '來', '淨', '及評', '九十六年', '別明細', '可觀察跡', '部分', '之依', '中', '其應', '正', '保費', '台北富邦商業銀行', '並依', '鴻夏戀', '一流', '不當', '請詳', '入入帳', '在', '依債權', '及保', '引述', '台幣', '三商美邦人壽保險', '註', '文件', '三星', '因為', '等', '向', '之妥', '一千七百', '用', '結果', '利', '遠東', '正確', '分攤', '估分', '另因', '開關鍵', '卅八', '請', '5', '上千', '上揚', '被', '流量', '完成', '並同', '一期', '社長', '使融', '最為', '其', '多', '之間', '主計', '持續', '土城', '有助', '億建築', '值估', '不符', '12', '表示', '事錄', '一再', '八', '堺', '則須', '一路', '並執', '以前', '公告', '十七所', '沒有', '一兆日圓', '6', '會計', '五日', '製', '三足鼎立', '二十七', '三點', '已', '或', '使用', '三成', '依所定', '其公', '其有', '星展', '別設', '最終', '金額', '依其會', '保證', '仍', '百', '值以', '以融', 'L ...

# %% [markdown]
# #### 計算 TFIDF 詞頻矩陣

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(data)

# %% [markdown]
# #### 顯示 TFIDF 詞頻矩陣大小

# %%
tfidf_matrix.shape
# Out:
# (3, 1151)

# %% [markdown]
# #### 顯示部份 TFIDF 詞頻矩陣中的字詞

# %%
words = tfidf_vectorizer.get_feature_names()
print(words[0:70])
# Out:
# ['交割', '以公允價值衡量之金融工具', '保險法', '保險法令之遵循', '備抵呆帳', '公允價值之會計估計及假設不確定性', '剩餘', '創業', '劇烈', '加權', '加總並', '動將', '動產', '務人', '務報', '勞動', '勾稽該', '匯合約', '匯換', '匯率', '占資', '危險', '原始放款資料', '原理', '及陽信', '及預', '反應', '取決', '受市', '受託從事期貨交易所取得之經紀手續費收入', '司及', '司受', '司法機關', '合乎', '合作社', '合度', '合計', '合資', '合金', '同意', '同為', '同類', '名單', '否選擇', '含折價', '含折溢價', '吸收', '呆帳', '告中', '告整', '命令', '品之開', '品別', '品質', '員工', '員工年資', '商品性', '商用', '商銀', '問答', '問題', '單一保單', '單中', '單數', '單資訊', '四七', '四三', '四二', '四六', '四十']

# %% [markdown]
# #### 顯示 TFIDF > 閥值 (limit) 的資料

# %%
limit = 0.1
wordsperdocument = 10
for i in range(len(data)):
    count = 0
    print('----Document : {0}----'.format(title[i]))
    for j in range(len(words)):
        if (tfidf_matrix[i,j] > limit) and (count != wordsperdocument):
            print(words[j], tfidf_matrix[i,j])
            count += 1
# Out:
# ----Document : 全部保險業----
# 創業 0.11250600862954063
# 已報未付 0.11953763416888694
# 權益投資標的 0.1265692597082332
# 簽單 0.1476641363262721
# 給付 0.10547438309019434
# 自留賠款準備 0.17579063848365725
# 負債適足 0.7242574305526679
# 資本 0.1476641363262721
# ----Document : 全部證券業----
# 應收證券融資款 0.2523207379256938
# 手續費 0.11039032284249103
# 有價證券 0.1261603689628469
# 期貨 0.17347050732391447
# 經紀手續費 0.11039032284249103
# 經紀手續費收入 0.8358124443788606
# 經紀手續費收入折讓 0.15770046120355863
# ----Document : 全部銀行業----
# 備抵呆帳 0.23162536619311416
# 回收率 0.13390841483039412
# 應收款 0.3528667688098224
# 授信 0.15924243925776596
# 放款 0.8450706719701899

# %% [markdown]
# #### 顯示文件相似性矩陣

# %%
dist = cosine_similarity(tfidf_matrix)
print(dist)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# #### 初始化 Count_vectorizer 物件，用以計算字頻

# %%
count_vectorizer = CountVectorizer(max_df = 1, min_df = 0, analyzer = 'word', stop_words = stopword)

# %% [markdown]
# #### 計算詞頻矩陣

# %%
count_matrix = count_vectorizer.fit_transform(data)

# %% [markdown]
# #### 顯示詞頻矩陣大小 (理論上與 TFIDF 詞頻矩陣相同)

# %%
count_matrix.shape
# Out:
# (3, 1151)

# %%
count_matrix.toarray()
# Out:
# array([[ 0,  8, 10, ...,  0,  0,  0],
#        [ 0,  0,  0, ...,  0,  0,  2],
#        [ 7,  0,  0, ...,  1,  3,  0]], dtype=int64)

# %%
countframe = pd.DataFrame(count_matrix.toarray().T, index = count_vectorizer.get_feature_names(), columns = title)
countframe.head(10)
# Out:
#                   全部保險業  全部證券業  全部銀行業
# 交割                    0      0      7
# 以公允價值衡量之金融工具          8      0      0
# 保險法                  10      0      0
# 保險法令之遵循               6      0      0
# 備抵呆帳                  0      0    128
# 公允價值之會計估計及假設不確定性      0      0      4
# 剩餘                    2      0      0
# 創業                   16      0      0
# 劇烈                    0      1      0
# 加權                    0      0      1

# %% [markdown]
# #### 初始化 WordCloud 物件

# %%
font = r"C:\Windows\Fonts\Microsoft JhengHei UI\msjh.ttc"
mask = np.array(Image.open("./cloudy.png"))
wordcloud = WordCloud(font_path=font, background_color = 'white', mask = mask)
wordcloud.fit_words(wordDict)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)

# %% [markdown]
# #### 顯示整體詞庫的字詞頻率及前十名

# %%
wordDict_key = count_vectorizer.get_feature_names()

wordDict = dict()
for i in range(len(wordDict_key)):
    wordDict_value = 0
    for j in range(len(data)):
        wordDict_value += count_matrix.toarray()[j].tolist()[i]
    wordDict[wordDict_key[i]] = wordDict_value

f = plt.figure(figsize=(15,20))
f.subplots_adjust(wspace = 0)

f.add_subplot(2, 1, 1)
wordcloud.fit_words(wordDict)
plt.title('All vocabularies', fontsize = 30)
plt.axis("off")
plt.imshow(wordcloud)
plt.savefig("TOTALKAM.png")

f.add_subplot(2, 1, 2)
sort = sorted(wordDict.items(), key=lambda x: x[1], reverse = True)
for i in range(10):
    plt.bar(sort[i][0], sort[i][1])
plt.title('Frequency v.s. Words', fontsize = 30)
plt.xticks(fontsize = 18, rotation=45)
plt.yticks(fontsize = 13, )
plt.savefig("TOTALBAR.png")

# %% [markdown]
# #### 顯示各個文件的字詞頻率及前十名

# %%
wordDict_key = count_vectorizer.get_feature_names()
plotind = 1
for i in range(len(data)):
    wordDict_value = count_matrix.toarray()[i].tolist()
    wordDict = dict()
    
    for j in range(len(wordDict_key)):
        if wordDict_value[j] != 0:
            wordDict[wordDict_key[j]] = wordDict_value[j]
            
    f = plt.figure(figsize=(30,6*len(data)))
    f.subplots_adjust(wspace = 0)

    f.add_subplot(len(data), 2, plotind)
    plotind += 1
    wordcloud.fit_words(wordDict)
    plt.title('{0}'.format(title[i]), fontsize = 30)
    plt.axis("off")
    plt.imshow(wordcloud)
    plt.savefig(title[i] + "文字雲.png")
    
    f.add_subplot(len(data), 2, plotind)
    plotind += 1
    sort = sorted(wordDict.items(), key=lambda x: x[1], reverse = True)
    for j in range(10 if (len(sort)>10) else len(sort)):
        plt.bar(sort[j][0], sort[j][1])
    plt.title('{0}'.format(title[i]), fontsize = 30)
    plt.xticks(fontsize = 18, rotation=45)
    plt.yticks(fontsize = 13)
    plt.savefig(title[i] + "長條圖.png")

# %% [markdown]
# ![stock](鴻海股價.png)

# %% [markdown]
# #### 定義 addstopword 及 adddict 函式

# %%
def addstopword(data):
    stop = []
    if os.path.isfile('./stay.txt'):
        with open('./stay.txt', 'rb') as f:
                text = f.read()
                encode = chardet.detect(text)
        stay = list(map(str.strip, open('./stay.txt', 'r+', encoding=encode['encoding']).readlines()))
    else:
        stay = []
    length = len(data)
    index = 0
    value = ''
    tmp = ''
    while(index != length):
        clear_output()
        if data[index] not in stay:
            print(data[index])
            value = input('Add to stop word [y:stopword/n:stayword/q:quit]: ')
            if value == 'y':
                if tmp == 'p': stay.remove(data[index])
                stop.append(data[index])
            elif value == 'n':
                if tmp == 'p': stop.remove(data[index])
                stay.append(data[index])
            elif value == 'p':
                index -= 2
            elif value == 'q':
                break
        tmp = value
        index += 1
    return stop, stay


def addword():
    word = []
    while(True):
        # clear_output()
        value = input('Add to dictionay word [q:quit]: ')
        if value == 'q':
            break
        else:
            word.append(value)
    return word

# %% [markdown]
# #### 新增停止詞彙 (半自動)

# %%
stop, stay = addstopword(tfidf_vectorizer.get_feature_names())
clear_output()
print(stop)
print('Save {0} words to stopword'.format(len(stop)))
savetofile('./stopword.txt', [stop])
print(stay)
print('Save {0} words to stayword'.format(len(stay)))
savetofile('./stay.txt', [stay])
# Out:
# 交割

# %% [markdown]
# #### 新增停止詞彙 (手動)

# %%
stop = addword()
clear_output()
print(stop)
print('Save {0} words to stopword'.format(len(stop)))
savetofile('./stopword.txt', [stop])

# %% [markdown]
# #### 新增自定義字典詞彙 (手動)

# %%
dictionary = addword()
clear_output()
print(dictionary)
print('Save {0} words to stopword'.format(len(dictionary)))
savetofile('./dict.txt', [dictionary])
